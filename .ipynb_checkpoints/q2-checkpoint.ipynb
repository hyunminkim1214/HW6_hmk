# %%
import random
n=10**2
randomdice1=[]
for i in range(n):
    randomdice1.append(random.randint(1,6))
count1=[0,0,0,0,0,0]
for i in randomdice1:
    if i==1:
        count1[0]=count1[0]+1
    elif i==2:
        count1[1]=count1[1]+1
    elif i==3:
        count1[2]=count1[2]+1
    elif i==4:
        count1[3]=count1[3]+1
    elif i==5:
        count1[4]=count1[4]+1
    else:
        count1[5]=count1[5]+1
print(count1)
n=10**3
randomdice1=[]
for i in range(n):
    randomdice1.append(random.randint(1,6))
count1=[0,0,0,0,0,0]
for i in randomdice1:
    if i==1:
        count1[0]=count1[0]+1
    elif i==2:
        count1[1]=count1[1]+1
    elif i==3:
        count1[2]=count1[2]+1
    elif i==4:
        count1[3]=count1[3]+1
    elif i==5:
        count1[4]=count1[4]+1
    else:
        count1[5]=count1[5]+1
print(count1)
n=10**4
randomdice1=[]
for i in range(n):
    randomdice1.append(random.randint(1,6))
count1=[0,0,0,0,0,0]
for i in randomdice1:
    if i==1:
        count1[0]=count1[0]+1
    elif i==2:
        count1[1]=count1[1]+1
    elif i==3:
        count1[2]=count1[2]+1
    elif i==4:
        count1[3]=count1[3]+1
    elif i==5:
        count1[4]=count1[4]+1
    else:
        count1[5]=count1[5]+1
print(count1)
n=10**5
randomdice1=[]
for i in range(n):
    randomdice1.append(random.randint(1,6))
count1=[0,0,0,0,0,0]
for i in randomdice1:
    if i==1:
        count1[0]=count1[0]+1
    elif i==2:
        count1[1]=count1[1]+1
    elif i==3:
        count1[2]=count1[2]+1
    elif i==4:
        count1[3]=count1[3]+1
    elif i==5:
        count1[4]=count1[4]+1
    else:
        count1[5]=count1[5]+1
print(count1)

# %%
import csv
