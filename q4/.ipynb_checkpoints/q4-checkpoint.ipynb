# %%
import csv
import pandas as pd
def main():

    print("Hello, World!")

 

if __name__ == '__main__':

 

    main()
# Out:
# Hello, World!

# %%
def get_inarr():

  data = pd.read_csv("subway4.csv")
  sorted = (pd.Series(map(int, data[1:].iloc[:, 2])) + pd.Series(map(int, data[1:].iloc[:, 4]))).sort_values(ascending=False)
  indices = sorted.index[:30]

  t_30 = []
  for idx in indices:
    t_30.append(tuple([data.iloc[idx, 1], sorted[idx]]))

  return t_30

# %%
def get_outarr():

  data = pd.read_csv("subway4.csv")
  sorted = (pd.Series(map(int, data[1:].iloc[:, 3])) + pd.Series(map(int, data[1:].iloc[:, 5]))).sort_values(ascending=False)
  indices = sorted.index[:30]

  t_30 = []
  for idx in indices:
    t_30.append(tuple([data.iloc[idx, 1], sorted[idx]]))

  return t_30

# %%
def get_allarr():

  data = pd.read_csv("subway4.csv")
  sorted = (pd.Series(map(int, data[1:].iloc[:, 3])) + pd.Series(map(int, data[1:].iloc[:, 5]))+pd.Series(map(int, data[1:].iloc[:, 2])) + pd.Series(map(int, data[1:].iloc[:, 4]))).sort_values(ascending=False)
  indices = sorted.index[:30]

  t_30 = []
  for idx in indices:
    t_30.append(tuple([data.iloc[idx, 1], sorted[idx]]))

  return t_30

# %%
x1=[]
y1=[]
for a,b in get_inarr():
    x1.append(a)
    y1.append(b)
x2=[]
y2=[]
for a,b in get_outarr():
    x2.append(a)
    y2.append(b)
x3=[]
y3=[]
for a,b in get_allarr():
    x3.append(a)
    y3.append(b)
print(get_allarr())
# Out:
# [('신대방', 683741), ('선릉', 602279), ('남구로', 591465), ('역삼', 589003), ('잠실나루', 578426), ('봉천', 573677), ('종합운동장', 550619), ('시청', 520825), ('삼성(무역센터)', 484131), ('대림(구로구청)', 475539), ('남부터미널(예술의전당)', 455565), ('낙성대(강감찬)', 436047), ('뚝섬', 424934), ('시청', 417949), ('신길', 411761), ('서대문', 401904), ('명학', 350294), ('국회의사당', 349670), ('구파발', 349368), ('우장산', 342074), ('쌍문', 338894), ('화곡', 338580), ('부천', 334888), ('창동', 319471), ('정부과천청사', 316349), ('동묘앞', 315636), ('화서', 315526), ('교대(법원.검찰청)', 315137), ('방배', 314010), ('오류동', 311986)]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False
plt.subplot(1,3,1)
plt.barh(x1,y1)
plt.subplot(1,3,2)
plt.barh(x2,y2)
plt.subplot(1,3,3)
plt.barh(x3,y3)
plt.subplots_adjust(
    wspace=3,  
    hspace=1)
